# %%
# R adv data mangling

# %%
## notes in 
## "2020.1023.RdataWrangleDay2.rst" 211L, 3673C written
## inet-dev-class/notes

# %%
library(tidyverse)

# %%
table4a
# Out:
#   country     1999   2000
# 1 Afghanistan    745   2666
# 2 Brazil       37737  80488
# 3 China       212258 213766

# %%
library(vroom)
# this library can load csv data at 1 GB/sec
# Out:
# Error in library(vroom): there is no package called ‘vroom’
# Traceback:
#
# 1. library(vroom)

# %%
table4a %>%
gather(key = "year",
       value = "cases", 
       c("1999", "2000"))
# Out:
#   country     year cases
# 1 Afghanistan 1999    745
# 2 Brazil      1999  37737
# 3 China       1999 212258
# 4 Afghanistan 2000   2666
# 5 Brazil      2000  80488
# 6 China       2000 213766

# %%
billboard %>% head
# Out:
#   artist       track                   date.entered wk1 wk2 wk3 wk4 wk5 wk6 wk7
# 1 2 Pac        Baby Don't Cry (Keep... 2000-02-26   87  82  72  77  87  94  99
# 2 2Ge+her      The Hardest Part Of ... 2000-09-02   91  87  92  NA  NA  NA  NA
# 3 3 Doors Down Kryptonite              2000-04-08   81  70  68  67  66  57  54
# 4 3 Doors Down Loser                   2000-10-21   76  76  72  69  67  65  55
# 5 504 Boyz     Wobble Wobble           2000-04-15   57  34  25  17  17  31  36
# 6 98^0         Give Me Just One Nig... 2000-08-19   51  39  34  26  26  19   2
#   ⋯ wk67 wk68 wk69 wk70 wk71 wk72 wk73 wk74 wk75 wk76
# 1 ⋯ NA   NA   NA   NA   NA   NA   NA   NA   NA   NA
# 2 ⋯ NA   NA   NA   NA   NA   NA   NA   NA   NA   NA
# 3 ⋯ NA   NA   NA   NA   NA   NA   NA   NA   NA   NA
# 4 ⋯ NA   NA   NA   NA   NA   NA   NA   NA   NA   NA
# 5 ⋯ NA   NA   NA   NA   NA   NA   NA   NA   NA   NA
# 6 ⋯ NA   NA   NA   NA   NA   NA   NA   NA   NA   NA

# %%
table2
# Out:
#    country     year type       count
# 1  Afghanistan 1999 cases             745
# 2  Afghanistan 1999 population   19987071
# 3  Afghanistan 2000 cases            2666
# 4  Afghanistan 2000 population   20595360
# 5  Brazil      1999 cases           37737
# 6  Brazil      1999 population  172006362
# 7  Brazil      2000 cases           80488
# 8  Brazil      2000 population  174504898
# 9  China       1999 cases          212258
# 10 China       1999 population 1272915272
# 11 China       2000 cases          213766
# 12 China       2000 population 1280428583

# %%
fish_encounters
# Out:
#     fish station seen
# 1   4842 Release 1
# 2   4842 I80_1   1
# 3   4842 Lisbon  1
# 4   4842 Rstr    1
# 5   4842 Base_TD 1
# 6   4842 BCE     1
# 7   4842 BCW     1
# 8   4842 BCE2    1
# 9   4842 BCW2    1
# 10  4842 MAE     1
# 11  4842 MAW     1
# 12  4843 Release 1
# 13  4843 I80_1   1
# 14  4843 Lisbon  1
# 15  4843 Rstr    1
# 16  4843 Base_TD 1
# 17  4843 BCE     1
# 18  4843 BCW     1
# 19  4843 BCE2    1
# 20  4843 BCW2    1
# 21  4843 MAE     1
# 22  4843 MAW     1
# 23  4844 Release 1
# 24  4844 I80_1   1
# 25  4844 Lisbon  1
# 26  4844 Rstr    1
# 27  4844 Base_TD 1
# 28  4844 BCE     1
# 29  4844 BCW     1
# 30  4844 BCE2    1
# ⋮   ⋮    ⋮       ⋮
# 85  4859 Lisbon  1
# 86  4859 Rstr    1
# 87  4859 Base_TD 1
# 88  4861 Release 1
# 89  4861 I80_1   1
# 90  4861 Lisbon  1
# 91  4861 Rstr    1
# 92  4861 Base_TD 1
# 93  4861 BCE     1
# 94  4861 BCW     1
# 95  4861 BCE2    1
# 96  4861 BCW2    1
# 97  4861 MAE     1
# 98  4861 MAW     1
# 99  4862 Release 1
# ...

# %%
dplyr::arrange(mtcars,desc(mpg))
# Out:
#    mpg  cyl disp  hp  drat wt    qsec  vs am gear carb
# 1  33.9 4    71.1  65 4.22 1.835 19.90 1  1  4    1
# 2  32.4 4    78.7  66 4.08 2.200 19.47 1  1  4    1
# 3  30.4 4    75.7  52 4.93 1.615 18.52 1  1  4    2
# 4  30.4 4    95.1 113 3.77 1.513 16.90 1  1  5    2
# 5  27.3 4    79.0  66 4.08 1.935 18.90 1  1  4    1
# 6  26.0 4   120.3  91 4.43 2.140 16.70 0  1  5    2
# 7  24.4 4   146.7  62 3.69 3.190 20.00 1  0  4    2
# 8  22.8 4   108.0  93 3.85 2.320 18.61 1  1  4    1
# 9  22.8 4   140.8  95 3.92 3.150 22.90 1  0  4    2
# 10 21.5 4   120.1  97 3.70 2.465 20.01 1  0  3    1
# 11 21.4 6   258.0 110 3.08 3.215 19.44 1  0  3    1
# 12 21.4 4   121.0 109 4.11 2.780 18.60 1  1  4    2
# 13 21.0 6   160.0 110 3.90 2.620 16.46 0  1  4    4
# 14 21.0 6   160.0 110 3.90 2.875 17.02 0  1  4    4
# 15 19.7 6   145.0 175 3.62 2.770 15.50 0  1  5    6
# 16 19.2 6   167.6 123 3.92 3.440 18.30 1  0  4    4
# 17 19.2 8   400.0 175 3.08 3.845 17.05 0  0  3    2
# ...

# %%
starwars$films[1]
# Out:
# [[1]]
# [1] "Revenge of the Sith"     "Return of the Jedi"
# [3] "The Empire Strikes Back" "A New Hope"
# [5] "The Force Awakens"

# %%
starwars %>% head
# Out:
#   name           height mass hair_color  skin_color  eye_color birth_year
# 1 Luke Skywalker 172     77  blond       fair        blue       19.0
# 2 C-3PO          167     75  NA          gold        yellow    112.0
# 3 R2-D2           96     32  NA          white, blue red        33.0
# 4 Darth Vader    202    136  none        white       yellow     41.9
# 5 Leia Organa    150     49  brown       light       brown      19.0
# 6 Owen Lars      178    120  brown, grey light       blue       52.0
#   gender homeworld species
# 1 male   Tatooine  Human
# 2 NA     Tatooine  Droid
# 3 NA     Naboo     Droid
# 4 male   Tatooine  Human
# 5 female Alderaan  Human
# 6 male   Tatooine  Human
#   films
# 1 Revenge of the Sith    , Return of the Jedi     , The Empire Strikes Back, A New Hope             , The Force Awakens
# 2 Attack of the Clones   , The Phantom Menace     , Revenge of the Sith    , Return of the Jedi     , The Empire Strikes Back, A New Hope
# ...

# %%
starwars %>% 
filter(gender == "female") %>%
arrange(desc(height))
# Out:
#    name               height mass hair_color skin_color          eye_color
# 1  Taun We            213      NA none       grey                black
# 2  Adi Gallia         184    50.0 none       dark                blue
# 3  Ayla Secura        178    55.0 none       blue                hazel
# 4  Shaak Ti           178    57.0 none       red, blue, white    black
# 5  Sly Moore          178    48.0 none       pale                white
# 6  Luminara Unduli    170    56.2 black      yellow              blue
# 7  Zam Wesell         168    55.0 blonde     fair, green, yellow yellow
# 8  Jocasta Nu         167      NA white      fair                blue
# 9  Barriss Offee      166    50.0 black      yellow              blue
# 10 Beru Whitesun lars 165    75.0 brown      light               blue
# 11 Dormé              165      NA brown      light               brown
# 12 Padmé Amidala      165    45.0 brown      light               brown
# ...

# %%
starwars %>% 
filter(height <= 180, height > 160) %>% 
nrow()
# Out:
# [1] 29

# %%
starwars %>% 
filter(height <= 180 & height > 160) %>% 
nrow()
# Out:
# [1] 29

# %%
starwars %>% 
filter(height <= 180 | height > 160) %>% 
nrow()
# Out:
# [1] 81

# %%
starwars$name
# Out:
#  [1] "Luke Skywalker"        "C-3PO"                 "R2-D2"
#  [4] "Darth Vader"           "Leia Organa"           "Owen Lars"
#  [7] "Beru Whitesun lars"    "R5-D4"                 "Biggs Darklighter"
# [10] "Obi-Wan Kenobi"        "Anakin Skywalker"      "Wilhuff Tarkin"
# [13] "Chewbacca"             "Han Solo"              "Greedo"
# [16] "Jabba Desilijic Tiure" "Wedge Antilles"        "Jek Tono Porkins"
# [19] "Yoda"                  "Palpatine"             "Boba Fett"
# [22] "IG-88"                 "Bossk"                 "Lando Calrissian"
# [25] "Lobot"                 "Ackbar"                "Mon Mothma"
# [28] "Arvel Crynyd"          "Wicket Systri Warrick" "Nien Nunb"
# [31] "Qui-Gon Jinn"          "Nute Gunray"           "Finis Valorum"
# [34] "Jar Jar Binks"         "Roos Tarpals"          "Rugor Nass"
# [37] "Ric Olié"              "Watto"                 "Sebulba"
# [40] "Quarsh Panaka"         "Shmi Skywalker"        "Darth Maul"
# ...

# %%
starwars %>% filter(grepl("ars", tolower(name)))
# Out:
#   name               height mass hair_color  skin_color eye_color birth_year
# 1 Owen Lars          178    120  brown, grey light      blue      52
# 2 Beru Whitesun lars 165     75  brown       light      blue      47
# 3 Quarsh Panaka      183     NA  black       dark       brown     62
# 4 Cliegg Lars        183     NA  brown       fair       blue      82
#   gender homeworld species
# 1 male   Tatooine  Human
# 2 female Tatooine  Human
# 3 male   Naboo     NA
# 4 male   Tatooine  Human
#   films                                                            vehicles
# 1 Attack of the Clones, Revenge of the Sith , A New Hope
# 2 Attack of the Clones, Revenge of the Sith , A New Hope
# 3 The Phantom Menace
# 4 Attack of the Clones
#   starships
# 1
# 2
# 3
# 4

# %%
starwars %>% filter(grepl("ars", tolower(name)))
# Out:
#   name               height mass hair_color  skin_color eye_color birth_year
# 1 Owen Lars          178    120  brown, grey light      blue      52
# 2 Beru Whitesun lars 165     75  brown       light      blue      47
# 3 Quarsh Panaka      183     NA  black       dark       brown     62
# 4 Cliegg Lars        183     NA  brown       fair       blue      82
#   gender homeworld species
# 1 male   Tatooine  Human
# 2 female Tatooine  Human
# 3 male   Naboo     NA
# 4 male   Tatooine  Human
#   films                                                            vehicles
# 1 Attack of the Clones, Revenge of the Sith , A New Hope
# 2 Attack of the Clones, Revenge of the Sith , A New Hope
# 3 The Phantom Menace
# 4 Attack of the Clones
#   starships
# 1
# 2
# 3
# 4

# %%
starwars %>% 
filter(str_detect(tolower(name), "ars"))
# Out:
#   name               height mass hair_color  skin_color eye_color birth_year
# 1 Owen Lars          178    120  brown, grey light      blue      52
# 2 Beru Whitesun lars 165     75  brown       light      blue      47
# 3 Quarsh Panaka      183     NA  black       dark       brown     62
# 4 Cliegg Lars        183     NA  brown       fair       blue      82
#   gender homeworld species
# 1 male   Tatooine  Human
# 2 female Tatooine  Human
# 3 male   Naboo     NA
# 4 male   Tatooine  Human
#   films                                                            vehicles
# 1 Attack of the Clones, Revenge of the Sith , A New Hope
# 2 Attack of the Clones, Revenge of the Sith , A New Hope
# 3 The Phantom Menace
# 4 Attack of the Clones
#   starships
# 1
# 2
# 3
# 4

# %%
starwars %>% 
filter(hair_color %in% c("black", "brown"))  %>% slice(1:6)
# Out:
#   name               height mass hair_color skin_color eye_color birth_year
# 1 Leia Organa        150     49  brown      light      brown      19
# 2 Beru Whitesun lars 165     75  brown      light      blue       47
# 3 Biggs Darklighter  183     84  black      light      brown      24
# 4 Chewbacca          228    112  brown      unknown    blue      200
# 5 Han Solo           180     80  brown      fair       brown      29
# 6 Wedge Antilles     170     77  brown      fair       hazel      21
#   gender homeworld species
# 1 female Alderaan  Human
# 2 female Tatooine  Human
# 3 male   Tatooine  Human
# 4 male   Kashyyyk  Wookiee
# 5 male   Corellia  Human
# 6 male   Corellia  Human
#   films
# 1 Revenge of the Sith    , Return of the Jedi     , The Empire Strikes Back, A New Hope             , The Force Awakens
# 2 Attack of the Clones, Revenge of the Sith , A New Hope
# 3 A New Hope
# ...

# %%
starwars$hair_color %in% c('black', 'brown')
# Out:
#  [1] FALSE FALSE FALSE FALSE  TRUE FALSE  TRUE FALSE  TRUE FALSE FALSE FALSE
# [13]  TRUE  TRUE FALSE FALSE  TRUE  TRUE FALSE FALSE  TRUE FALSE FALSE  TRUE
# [25] FALSE FALSE FALSE  TRUE  TRUE FALSE  TRUE FALSE FALSE FALSE FALSE FALSE
# [37]  TRUE  TRUE FALSE  TRUE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [49] FALSE FALSE  TRUE FALSE FALSE FALSE FALSE FALSE  TRUE  TRUE  TRUE FALSE
# [61]  TRUE  TRUE  TRUE FALSE  TRUE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE
# [73] FALSE FALSE FALSE FALSE FALSE  TRUE  TRUE FALSE FALSE  TRUE  TRUE  TRUE
# [85] FALSE FALSE  TRUE

# %%
?str_detect
# Out:
# str_detect               package:stringr               R Documentation
#
# g.
#
# n:
#
#      Vectorised over ‘string’ and ‘pattern’. Equivalent to
#      ‘grepl(pattern, x)’. See ‘str_which()’ for an equivalent to
#      ‘grep(pattern, x)’.
#
# e:
#
#      str_detect(string, pattern, negate = FALSE)
#
# s:
#
#   string: Input vector. Either a character vector, or something
#           coercible to one.
#
#  pattern: Pattern to look for.
#
#           The default interpretation is a regular expression, as
#           described in stringi::stringi-search-regex. Control options
#           with ‘regex()’.
#
#           Match a fixed string (i.e. by comparing only bytes), using
#           ‘fixed()’. This is fast, but approximate. Generally, for
#           matching human text, you'll want ‘coll()’ which respects
#           character matching rules for the specified locale.
#
#           Match character, word, line and sentence boundaries with
# ...

# %%
#install.packages(pacman)

if (!require("pacman")) install.packages("pacman")
pacman::p_load(
  tidyverse, # for the tidyverse framework
  gapminder # toy data
  )
# Out:
# Loading required package: pacman
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘pacman’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
#
# gapminder installed

# %%
library(pacman)

# %%
#old:
#smaple_frac(0.10, replace = FALSE )  # take 10% random rows, do NOT replace ?

#new:
starwars %>% 
slice_sample( prop = 0.10, replace = FALSE )
#kinda like slice(1:6) idea above.
# Out:
# Error in slice_sample(., prop = 0.1, replace = FALSE): could not find function "slice_sample"
# Traceback:
#
# 1. starwars %>% slice_sample(prop = 0.1, replace = FALSE)
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. withVisible(function_list[[k]](value))
# 8. function_list[[k]](value)

# %%
starwars %>% slice_max( height, n=10)
# Out:
# Error in slice_max(., height, n = 10): could not find function "slice_max"
# Traceback:
#
# 1. starwars %>% slice_max(height, n = 10)
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. withVisible(function_list[[k]](value))
# 8. function_list[[k]](value)

# %%
msleep %>% head
# Out:
#   name                       genus      vore  order        conservation
# 1 Cheetah                    Acinonyx   carni Carnivora    lc
# 2 Owl monkey                 Aotus      omni  Primates     NA
# 3 Mountain beaver            Aplodontia herbi Rodentia     nt
# 4 Greater short-tailed shrew Blarina    omni  Soricomorpha lc
# 5 Cow                        Bos        herbi Artiodactyla domesticated
# 6 Three-toed sloth           Bradypus   herbi Pilosa       NA
#   sleep_total sleep_rem sleep_cycle awake brainwt bodywt
# 1 12.1         NA              NA   11.9       NA  50.000
# 2 17.0        1.8              NA    7.0  0.01550   0.480
# 3 14.4        2.4              NA    9.6       NA   1.350
# 4 14.9        2.3       0.1333333    9.1  0.00029   0.019
# 5  4.0        0.7       0.6666667   20.0  0.42300 600.000
# 6 14.4        2.2       0.7666667    9.6       NA   3.850

# %%
msleep %>% select(where(is.numeric))
# Out:
# Error: This tidyselect interface doesn't support predicates yet.
# ℹ Contact the package author and suggest using `eval_select()`.
# Traceback:
#
# 1. msleep %>% select(where(is.numeric))
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. withVisible(function_list[[k]](value))
# 8. function_list[[k]](value)
# 9. select(., where(is.numeric))
# 10. select.data.frame(., where(is.numeric))
# 11. tidyselect::vars_select(tbl_vars(.data), !!!enquos(...))
# 12. eval_select_impl(NULL, .vars, expr(c(!!!dots)), include = .include,
#   .     exclude = .exclude, strict = .strict, name_spec = unique_name_spec,
#   .     uniquely_named = TRUE)
# 13. with_subscript_errors(vars_select_eval(vars, expr, strict, data = x,
#   .     name_spec = name_spec, uniquely_named = uniquely_named, allow_rename = allow_rename,
# ...

# %%
msleep %>% slect(contains("sleep"))
# Out:
# Error in slect(., contains("sleep")): could not find function "slect"
# Traceback:
#
# 1. msleep %>% slect(contains("sleep"))
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. withVisible(function_list[[k]](value))
# 8. function_list[[k]](value)

# %%
# day 2

# %%
if (!require("pacman")) install.packages("pacman")
pacman::p_load(
  tidyverse, # for the tidyverse framework
  gapminder, # toy example 
  kableExtra, 
  flextable 
  )
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘webshot’
#
#
#
# kableExtra installed
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘zip’, ‘officer’
#
#
#
# flextable installed

# %%
gapminder %>% select(1:5) %>% head
# Out:
#   country     continent year lifeExp pop
# 1 Afghanistan Asia      1952 28.801   8425333
# 2 Afghanistan Asia      1957 30.332   9240934
# 3 Afghanistan Asia      1962 31.997  10267083
# 4 Afghanistan Asia      1967 34.020  11537966
# 5 Afghanistan Asia      1972 36.088  13079460
# 6 Afghanistan Asia      1977 38.438  14880372

# %%
gapminder %>% count(continent, sort = TRUE)
# Out:
#   continent n
# 1 Africa    624
# 2 Asia      396
# 3 Europe    360
# 4 Americas  300
# 5 Oceania    24

# %%
gapminder %>% count(continent) %>% arrange(desc)
# Out:
# Error: cannot arrange column of class 'function' at position 1
# Traceback:
#
# 1. gapminder %>% count(continent) %>% arrange(desc)
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. withVisible(function_list[[k]](value))
# 8. function_list[[k]](value)
# 9. arrange(., desc)
# 10. arrange.tbl_df(., desc)
# 11. arrange_impl(.data, dots, environment())

# %%
gapminder %>%
group_by(continent, year) %>% count()
# Out:
#    continent year n
# 1  Africa    1952 52
# 2  Africa    1957 52
# 3  Africa    1962 52
# 4  Africa    1967 52
# 5  Africa    1972 52
# 6  Africa    1977 52
# 7  Africa    1982 52
# 8  Africa    1987 52
# 9  Africa    1992 52
# 10 Africa    1997 52
# 11 Africa    2002 52
# 12 Africa    2007 52
# 13 Americas  1952 25
# 14 Americas  1957 25
# 15 Americas  1962 25
# 16 Americas  1967 25
# 17 Americas  1972 25
# 18 Americas  1977 25
# 19 Americas  1982 25
# 20 Americas  1987 25
# 21 Americas  1992 25
# 22 Americas  1997 25
# 23 Americas  2002 25
# 24 Americas  2007 25
# 25 Asia      1952 33
# 26 Asia      1957 33
# 27 Asia      1962 33
# 28 Asia      1967 33
# 29 Asia      1972 33
# 30 Asia      1977 33
# 31 Asia      1982 33
# 32 Asia      1987 33
# 33 Asia      1992 33
# 34 Asia      1997 33
# 35 Asia      2002 33
# 36 Asia      2007 33
# 37 Europe    1952 30
# 38 Europe    1957 30
# 39 Europe    1962 30
# 40 Europe    1967 30
# 41 Europe    1972 30
# 42 Europe    1977 30
# ...

# %%
summarise(gapminder)
# Out:
#
# 1

# %%
# https://github.com/dlab-berkeley/advanced-data-wrangling-in-R/blob/master/code/03_summarizing.Rmd
#[10:02]
#challenge #4
#------------

gapminder %>% head(3)
# Out:
#   country     continent year lifeExp pop      gdpPercap
# 1 Afghanistan Asia      1952 28.801   8425333 779.4453
# 2 Afghanistan Asia      1957 30.332   9240934 820.8530
# 3 Afghanistan Asia      1962 31.997  10267083 853.1007

# %%
LL = c(TRUE, FALSE, TRUE, FALSE)
sum(LL)
mean(LL)
# Out:
# [1] 2
# [1] 0.5

# %%
df = sample( c(1:10), 10) 
df
sum(df)
    
cumsum(df)
# Out:
#  [1]  9  6  2  1  7  3  8  4 10  5
# [1] 55
#  [1]  9 15 17 18 25 28 36 40 50 55

# %%
nested <- gapminder %>%
  group_by(country, continent) %>%
  nest() 
head(nested)
nested$data[[1]]
# Out:
#   country     continent
# 1 Afghanistan Asia
# 2 Albania     Europe
# 3 Algeria     Africa
# 4 Angola      Africa
# 5 Argentina   Americas
# 6 Australia   Oceania
#   data
# 1 1.952000e+03, 1.957000e+03, 1.962000e+03, 1.967000e+03, 1.972000e+03, 1.977000e+03, 1.982000e+03, 1.987000e+03, 1.992000e+03, 1.997000e+03, 2.002000e+03, 2.007000e+03, 2.880100e+01, 3.033200e+01, 3.199700e+01, 3.402000e+01, 3.608800e+01, 3.843800e+01, 3.985400e+01, 4.082200e+01, 4.167400e+01, 4.176300e+01, 4.212900e+01, 4.382800e+01, 8.425333e+06, 9.240934e+06, 1.026708e+07, 1.153797e+07, 1.307946e+07, 1.488037e+07, 1.288182e+07, 1.386796e+07, 1.631792e+07, 2.222742e+07, 2.526840e+07, 3.188992e+07, 7.794453e+02, 8.208530e+02, 8.531007e+02, 8.361971e+02, 7.399811e+02, 7.861134e+02, 9.780114e+02, 8.523959e+02, 6.493414e+02, 6.353414e+02, 7.267341e+02, 9.745803e+02
# ...

# %% [markdown]
# [11:11]
# relational database
# PK, FK, join
# df
# rowid_to_columnt("ID")
# from flight data example

# %%
## notes in 
## "2020.1023.RdataWrangleDay2.rst" 211L, 3673C written
## inet-dev-class/notes
